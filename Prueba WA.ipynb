# %%
mensaje='Hola'

# %%
import json
from ibm_watson import AssistantV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('nNAUs2mpx7W4a830bsIkhzAd4_j6OY-JOZaI_mbxBPvi')
assistant = AssistantV1(
    version='2021-06-14',
    authenticator = authenticator
)

assistant.set_service_url('https://api.us-south.assistant.watson.cloud.ibm.com/instances/c1fdd3e2-9daf-421b-865a-64fe4c6c61a6')

response = assistant.message(
    workspace_id='d1da6478-fcba-4c24-aecb-054d5e2c34fe',
    input={
        'text': mensaje
    }
).get_result()



print(response['output']['text'])
# Out:
# {
#   "intents": [
#     {
#       "intent": "Saludo_",
#       "confidence": 1
#     }
#   ],
#   "entities": [],
#   "input": {
#     "text": "Hola"
#   },
#   "output": {
#     "generic": [
#       {
#         "response_type": "text",
#         "text": "2022-05-04 18\n2022-05-04 18:13:59\n2020-05-04 18:13:59\n2023-05-04 18:13:59\n"
#       }
#     ],
#     "text": [
#       "2022-05-04 18\n2022-05-04 18:13:59\n2020-05-04 18:13:59\n2023-05-04 18:13:59\n"
#     ],
#     "nodes_visited": [
#       "node_7_1651686215126"
#     ],
#     "log_messages": []
#   },
#   "context": {
#     "conversation_id": "f9b0dd75-56cf-4a2e-b73f-a9e44fd81966",
#     "system": {
#       "initialized": true,
#       "dialog_stack": [
#         {
#           "dialog_node": "root"
#         }
#       ],
#       "dialog_turn_counter": 1,
#       "dialog_request_counter": 1,
#       "_node_output_map": {
#         "node_7_1651686215126": {
#           "0": [
#             0
#           ]
#         }
# ...

# %%
# !pip install --upgrade "ibm-watson>=6.0.0"
# Out:
# ...
#      |████████████████████████████████| 338 kB 17.0 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 68 kB 8.9 MB/s  eta 0:00:01
# ...
#   Created wheel for ibm-watson: filename=ibm_watson-6.0.0-py3-none-any.whl size=336807 sha256=4241f24d97a35d79fb77ebe217f01900fdb4160e7d92babdebee6c0a5b048df0
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/d1/cd/2c/b423c19d8590c90ff21522a4be4b88b30e574b6f6a2b8cb557
# Successfully built ibm-watson
# ...

# %%
print(response['output']['text'][0])
# Out:
# 2022-05-04 18
# 2022-05-04 18:13:59
# 2020-05-04 18:13:59
# 2023-05-04 18:13:59
